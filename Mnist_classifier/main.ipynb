# %%
# !python3 "/content/drive/MyDrive/Mnist_classifier/train.py"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Train: Epoch5,Loss:0.18286764357292312,ACC:0.9463682432432432
# Train: Epoch5,Loss:0.18273950146718157,ACC:0.9464037698412698
# Train: Epoch5,Loss:0.18295392850723868,ACC:0.9463896592709984
# Train: Epoch5,Loss:0.1829944113711532,ACC:0.9463261471518988
# Train: Epoch5,Loss:0.18295740215828726,ACC:0.9463615718799369
# Train: Epoch5,Loss:0.18281805844043236,ACC:0.9464215299684543
# Train: Epoch5,Loss:0.18279199552993605,ACC:0.9464074803149606
# Train: Epoch5,Loss:0.18266130120159602,ACC:0.946467177672956
# Train: Epoch5,Loss:0.18251327437815057,ACC:0.9465021585557299
# Train: Epoch5,Loss:0.18243771207264878,ACC:0.9464880485893417
# Train: Epoch5,Loss:0.1823004484963669,ACC:0.9465228873239436
# Train: Epoch5,Loss:0.18219206584326458,ACC:0.9466064453125
# Train: Epoch5,Loss:0.18234583628240408,ACC:0.9465434867394695
# Train: Epoch5,Loss:0.18235991224124332,ACC:0.946505062305296
# Train: Epoch5,Loss:0.18239884166275824,ACC:0.9464910575427683
# ...
