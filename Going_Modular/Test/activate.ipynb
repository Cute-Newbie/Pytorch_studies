# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !python /content/drive/MyDrive/Pytorch/Test/train.py
# Out:
# Image-path directory alreay exist skip dowload
# ...
# unzipping data
# Done
# 0
# Train_ Loss:1.1017642617225647,Train_acc:0.28125
# 10
# Train_ Loss:1.104363575577736,Train_acc:0.28125
# 20
# Train_ Loss:1.1007129549980164,Train_acc:0.28125
# 30
# Train_ Loss:1.1026319861412048,Train_acc:0.28125
# 40
# Train_ Loss:1.1018677055835724,Train_acc:0.3203125
# loss : 1.0966848134994507 acc : 0.2604166666666667
